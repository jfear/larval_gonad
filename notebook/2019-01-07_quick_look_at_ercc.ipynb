# %% [markdown]
# # Quick Look at ERCC

# %% [markdown]
# Here I am taking a quick look to make sure I have everything I need for the ERCCs.

# %%
import os
import sys
import re
from pathlib import Path

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
from larval_gonad.normalization import tpm

# %%
sample_table = pd.read_csv('../bulk-rnaseq-wf/config/sampletable.tsv', sep='\t', index_col=0)
sample_to_ercc = sample_table.ercc

# %%
cnts = pd.read_parquet('../output/bulk-rnaseq-wf/aggregation/gene_level_counts.parquet')

# %%
# !head
# Out:
# ERCC-00002	1061
# ERCC-00003	1023
# ERCC-00004	523
# ERCC-00007	1135
# ERCC-00009	984
# ERCC-00012	994
# ERCC-00013	808
# ERCC-00014	1957
# ERCC-00016	844
# ERCC-00017	1136

# %%
gene_lens = pd.read_csv('../output/gene_ts_lengths.tsv', sep='\t', index_col=0).iloc[:, 0]
ercc_lens = pd.read_csv('/data/LCDB/lcdb-references/ercc/srm2374/fasta/ercc_srm2374.chromsizes', sep='\t', index_col=0).iloc[:, 0]
gene_ercc_lens = pd.concat([gene_lens, ercc_lens])

# %%
norm = tpm(cnts, gene_ercc_lens).dropna()

# %%
ercc_norm = norm[norm.index.str.startswith('ERCC')].T.join(sample_to_ercc).set_index('ercc', append=True).sort_index(level=1)

# %%
ercc_grp_a = ercc_cnts.groupby('ercc').get_group('A')

# %%
ercc_grp_a
# Out:
#               ERCC-00002  ERCC-00003  ERCC-00004  ERCC-00007  ERCC-00009  \
#         ercc
# A11_FT  A            121           0           1           0           9
# A1_TF   A             86           0           3           1           3
# A3_TF   A            183           1           4           0          22
# A9_FT   A            253           0           3           0          18
# B5_TCP  A            125           0           0           0          11
# B7_TCP  A             40           0           0           0           8
# C1_TDT  A             11           0           0           0           2
# C3_TDT  A             49           0           1           0           5
# F11_TDP A             14           0           0           0           1
# F9_TDP  A            436           4           1           3          35
#
#               ERCC-00012  ERCC-00013  ERCC-00014  ERCC-00016  ERCC-00017  \
#         ercc
# A11_FT  A             27           0           0           0           5
# A1_TF   A             27           0           0           0           6
# A3_TF   A             45           1           0           0          13
# A9_FT   A             76           0           0           0          18
# B5_TCP  A             34           0           2           1           9
# B7_TCP  A             19           0           0           0           3
# C1_TDT  A              9           0           0           0           0
# C3_TDT  A             13           0           0           0           3
# F11_TDP A              5           0           1           0           1
# F9_TDP  A            101           0           4           6          21
#
#                  ...      ERCC-00157  ERCC-00158  ERCC-00160  ERCC-00162  \
#         ercc     ...
# A11_FT  A        ...              21          26          48           4
# A1_TF   A        ...              25          21          43           0
# A3_TF   A        ...              47          37          60           0
# A9_FT   A        ...              51          62          98           2
# B5_TCP  A        ...              29          24          53           3
# B7_TCP  A        ...               7          13          21           3
# C1_TDT  A        ...               7           7           6           1
# C3_TDT  A        ...               5           8          25           1
# F11_TDP A        ...               9           6           7           1
# F9_TDP  A        ...              91         101         148          19
#
#               ERCC-00163  ERCC-00164  ERCC-00165  ERCC-00168  ERCC-00170  \
#         ercc
# A11_FT  A              0           1           0           1           1
# A1_TF   A              0           1           1           1           2
# A3_TF   A              0           1           0           1           0
# A9_FT   A              0           1           0           5           2
# B5_TCP  A              0           3           0           7           0
# B7_TCP  A              0           0           0           2           0
# C1_TDT  A              0           0           0           1           0
# C3_TDT  A              0           0           0           0           0
# F11_TDP A              0           0           0           0           0
# F9_TDP  A              1           6           3          16           1
#
#               ERCC-00171
#         ercc
# A11_FT  A              6
# A1_TF   A              6
# A3_TF   A             11
# A9_FT   A              5
# B5_TCP  A              2
# B7_TCP  A              0
# C1_TDT  A              3
# C3_TDT  A              0
# F11_TDP A              1
# F9_TDP  A             20
#
# [10 rows x 96 columns]

# %%
# !ls /data/LCDB/lcdb-references/ercc/srm2374/gtf
# Out:
# ercc_srm2374.gtf  ercc_srm2374.gtf.gz.log
