# %%
import os
import sys
from pathlib import Path
from tempfile import NamedTemporaryFile

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
from larval_gonad.notebook import Nb
from larval_gonad.gene_ontology import run_fly, run_flyslim

# %%
# Setup notebook
nbconfig = Nb.setup_notebook(seurat_dir='../scrnaseq-wf/data/scrnaseq_combine_force')
# Out:
# last updated: 2018-08-03
# Git hash: 64534f58712a8f53dd67f4d600a0bffd8919a9fc

# %%
background = nbconfig.seurat.get_normalized_read_counts().index.unique().tolist()

# %%
biomarkers = nbconfig.seurat.get_biomarkers('res.0.6')

def analyze_cluster(cluster, func):
    cluster_genes = biomarkers.query(f'cluster == {cluster} & p_val_adj <= 0.01').index.tolist()
    return func(cluster_genes, background, cutoff=0.05, return_obj=True)

# %%
dfs = []
for cluster in range(12):
    results, goeaobj = analyze_cluster(cluster, run_flyslim)
    with NamedTemporaryFile() as tmp:
        goeaobj.wr_tsv(tmp.name, results)
        df = pd.read_csv(tmp.name, sep='\t')
    df.drop('study_items', inplace=True, axis=1)
    df = df.assign(cluster=cluster)
    dfs.append(df)

go_results = pd.concat(dfs).set_index('# GO')
go_results.cluster = go_results.cluster.replace(nbconfig.cluster_annot)
summary = go_results.groupby('name')['cluster'].value_counts().to_frame().drop('cluster', axis=1).reset_index(level=1)

go_results.to_csv('../output/2018-08-03_go_slim_analysis_results.tsv', sep='\t')
summary.to_csv('../output/2018-08-03_go_slim_analysis_summary.tsv', sep='\t')
# Out:
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    565 out of    736 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   113 GO terms are associated with 565 of 736 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      37 items WROTE: /tmp/tmpu7is_6cf
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    310 out of    348 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   115 GO terms are associated with 310 of 348 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      30 items WROTE: /tmp/tmpb60_hxpt
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,370 out of  1,744 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   126 GO terms are associated with 1,370 of 1,744 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      66 items WROTE: /tmp/tmpc_bej1xu
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,181 out of  1,417 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   130 GO terms are associated with 1,181 of 1,417 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      32 items WROTE: /tmp/tmp89iiu4sx
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    531 out of    581 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   129 GO terms are associated with 531 of 581 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      44 items WROTE: /tmp/tmpzc2273es
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    585 out of    616 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   131 GO terms are associated with 585 of 616 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      56 items WROTE: /tmp/tmpg9sul5go
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,313 out of  1,383 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   136 GO terms are associated with 1,313 of 1,383 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      77 items WROTE: /tmp/tmpktfjxqx9
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    603 out of    637 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   133 GO terms are associated with 603 of 637 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      72 items WROTE: /tmp/tmp9dac1__u
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    681 out of    733 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   136 GO terms are associated with 681 of 733 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      73 items WROTE: /tmp/tmpa78y02w1
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    468 out of    507 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   128 GO terms are associated with 468 of 507 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      41 items WROTE: /tmp/tmpqqzfaxpe
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#     94 out of    108 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   78 GO terms are associated with 94 of 108 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      13 items WROTE: /tmp/tmp7arctgf0
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,410 out of  1,805 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   128 GO terms are associated with 1,410 of 1,805 study items
#   143 GO terms are associated with 11,166 of 14,476 population items
#      73 items WROTE: /tmp/tmp0ar_o8wq

# %%
dfs = []
for cluster in range(12):
    results, goeaobj = analyze_cluster(cluster, run_fly)
    with NamedTemporaryFile() as tmp:
        goeaobj.wr_tsv(tmp.name, results)
        df = pd.read_csv(tmp.name, sep='\t')
    df.drop('study_items', inplace=True, axis=1)
    df = df.assign(cluster=cluster)
    dfs.append(df)

go_results = pd.concat(dfs).set_index('# GO')
go_results.cluster = go_results.cluster.replace(nbconfig.cluster_annot)
summary = go_results.groupby('name')['cluster'].value_counts().to_frame().drop('cluster', axis=1).reset_index(level=1)

go_results.to_csv('../output/2018-08-03_go_analysis_results.tsv', sep='\t')
summary.to_csv('../output/2018-08-03_go_analysis_summary.tsv', sep='\t')
# Out:
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    565 out of    736 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   682 GO terms are associated with 565 of 736 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      27 items WROTE: /tmp/tmpief4eeuq
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    310 out of    348 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   992 GO terms are associated with 310 of 348 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      39 items WROTE: /tmp/tmpfjdz078w
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,370 out of  1,744 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,648 GO terms are associated with 1,370 of 1,744 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      70 items WROTE: /tmp/tmp9mebdrcv
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,181 out of  1,417 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,922 GO terms are associated with 1,181 of 1,417 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      34 items WROTE: /tmp/tmpzi0hje28
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    531 out of    581 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,776 GO terms are associated with 531 of 581 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      55 items WROTE: /tmp/tmp61kigjxf
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    585 out of    616 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,843 GO terms are associated with 585 of 616 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      73 items WROTE: /tmp/tmp6mchyav7
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,313 out of  1,383 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   2,645 GO terms are associated with 1,313 of 1,383 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#     309 items WROTE: /tmp/tmpvko5eis0
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    603 out of    637 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   2,196 GO terms are associated with 603 of 637 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#     320 items WROTE: /tmp/tmpdie77zjn
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    681 out of    733 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   2,264 GO terms are associated with 681 of 733 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#     266 items WROTE: /tmp/tmp9dni61mn
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#    468 out of    507 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,401 GO terms are associated with 468 of 507 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      65 items WROTE: /tmp/tmpx6qc1tpu
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#     94 out of    108 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   325 GO terms are associated with 94 of 108 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#       7 items WROTE: /tmp/tmpkprg4tru
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 11,166 out of 14,476 population items found in association
# Calculating uncorrected p-values using fisher_scipy_stats
#  1,410 out of  1,805 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,708 GO terms are associated with 1,410 of 1,805 study items
#   7,609 GO terms are associated with 11,166 of 14,476 population items
#      73 items WROTE: /tmp/tmpzip8s1ny

# %%
go_results.head()
# Out:
#             NS enrichment                                               name  \
# # GO
# GO:0008150  BP          e                                 biological_process
# GO:0006123  BP          e  mitochondrial electron transport, cytochrome c...
# GO:0006355  BP          p         regulation of transcription, DNA-templated
# GO:0035971  BP          e               peptidyl-histidine dephosphorylation
# GO:0007291  BP          e                            sperm individualization
#
#            ratio_in_study ratio_in_pop  p_uncorrected  depth  study_count  \
# # GO
# GO:0008150        252/736   1647/14476   1.527153e-64      0          252
# GO:0006123          8/736     15/14476   2.012627e-07      8            8
# GO:0006355          0/736    283/14476   6.894252e-07      9            0
# GO:0035971          4/736      4/14476   6.630571e-06      8            4
# GO:0007291         11/736     51/14476   4.011487e-05      4           11
#
#                 p_fdr_bh                    cluster
# # GO
# GO:0008150  1.162011e-60  Late 1º Spermatocytes (0)
# GO:0006123  2.552346e-04  Late 1º Spermatocytes (0)
# GO:0006355  6.137969e-04  Late 1º Spermatocytes (0)
# GO:0035971  2.802890e-03  Late 1º Spermatocytes (0)
# GO:0007291  1.346114e-02  Late 1º Spermatocytes (0)

# %%
summary.head()
# Out:
#                                                     cluster
# name
# 'de novo' protein folding                 Spermatogonia (6)
# 4 iron, 4 sulfur cluster binding                Unknown (9)
# 7S RNA binding                            Spermatogonia (6)
# ACF complex                               Spermatogonia (6)
# ATP binding                       Late 1º Spermatocytes (0)

# %%
summary
# Out:
#                                                                        cluster
# name
# 'de novo' protein folding                                    Spermatogonia (6)
# 4 iron, 4 sulfur cluster binding                                   Unknown (9)
# 7S RNA binding                                               Spermatogonia (6)
# ACF complex                                                  Spermatogonia (6)
# ATP binding                                          Late 1º Spermatocytes (0)
# ATP binding                                                  Spermatogonia (6)
# ATP binding                                                       Unknown (11)
# ATP hydrolysis coupled proton transport                   Early Cyst Cells (5)
# ATP hydrolysis coupled proton transport                    Late Cyst Cells (4)
# ATP hydrolysis coupled proton transport                     Mid Cyst Cells (1)
# ATP hydrolysis coupled proton transport                            Unknown (9)
# ATP synthesis coupled proton transport                    Early Cyst Cells (5)
# ATP synthesis coupled proton transport                     Late Cyst Cells (4)
# ATP synthesis coupled proton transport                      Mid Cyst Cells (1)
# ATP synthesis coupled proton transport                             Unknown (9)
# ATP-dependent RNA helicase activity                          Spermatogonia (6)
# ATPase activity                                              Spermatogonia (6)
# ATPase activity, coupled                             Late 1º Spermatocytes (0)
# BMP signaling pathway                                  Terminal Epithelium (7)
# CCR4-NOT core complex                                        Spermatogonia (6)
# COP9 signalosome                                             Spermatogonia (6)
# Cajal body                                                   Spermatogonia (6)
# Cul4-RING E3 ubiquitin ligase complex                        Spermatogonia (6)
# DNA binding                                          Late 1º Spermatocytes (0)
# DNA binding                                           Mid 1º Spermatocytes (2)
# DNA binding                                                  Spermatogonia (6)
# DNA binding                                            Terminal Epithelium (7)
# DNA binding                                                       Unknown (11)
# DNA binding transcription factor activity           Early 1º Spermatocytes (3)
# DNA binding transcription factor activity            Late 1º Spermatocytes (0)
# ...                                                                        ...
# ubiquinol-cytochrome-c reductase activity                 Early Cyst Cells (5)
# ubiquinol-cytochrome-c reductase activity                   Mid Cyst Cells (1)
# ubiquinol-cytochrome-c reductase activity                          Unknown (9)
# ubiquinone binding                                                 Unknown (9)
# ubiquitin activating enzyme binding                          Spermatogonia (6)
# ubiquitin-dependent ERAD pathway                             Spermatogonia (6)
# ubiquitin-dependent protein catabolic process                Spermatogonia (6)
# ubiquitin-protein transferase activity              Early 1º Spermatocytes (3)
# unfolded protein binding                            Early 1º Spermatocytes (3)
# unfolded protein binding                                     Spermatogonia (6)
# vacuolar proton-transporting V-type ATPase, V0 ...                 Unknown (9)
# vacuolar proton-transporting V-type ATPase, V1 ...        Early Cyst Cells (5)
# vacuolar proton-transporting V-type ATPase, V1 ...         Late Cyst Cells (4)
# vacuolar proton-transporting V-type ATPase, V1 ...          Mid Cyst Cells (1)
# vacuolar proton-transporting V-type ATPase, V1 ...                 Unknown (9)
# ventral cord development                              Mid 1º Spermatocytes (2)
# ventral cord development                                     Pigment Cells (8)
# ventral cord development                               Terminal Epithelium (7)
# ventral cord development                                          Unknown (11)
# ventral furrow formation                                     Pigment Cells (8)
# wing disc anterior/posterior pattern formation         Terminal Epithelium (7)
# wing disc development                                        Pigment Cells (8)
# wing disc development                                  Terminal Epithelium (7)
# wing disc dorsal/ventral pattern formation                   Pigment Cells (8)
# wing disc dorsal/ventral pattern formation             Terminal Epithelium (7)
# wing disc pattern formation                            Terminal Epithelium (7)
# wound healing                                                Pigment Cells (8)
# wound healing                                          Terminal Epithelium (7)
# zonula adherens                                        Terminal Epithelium (7)
# zonula adherens assembly                               Terminal Epithelium (7)
#
# [1338 rows x 1 columns]

# %%
summary.index.unique().shape
# Out:
# (775,)
