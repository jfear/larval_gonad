# %%
import numpy as np
import scipy.io
import pandas as pd

import scrublet as scr

# %%
barcodes = '../output/cellranger-wf/testis2/outs/raw_gene_bc_matrices/dmelr6-26/barcodes.tsv'
mtx = '../output/cellranger-wf/testis2/outs/raw_gene_bc_matrices/dmelr6-26/matrix.mtx' 
cell_calls = '../output/cellselection-wf/testis2_combined_cell_calls.feather'

# %%
bcs = pd.read_csv(barcodes, header=None).iloc[:, 0].map(lambda x: 'rep1_' + x.replace('-1', ''))

# %%
(
    pd.read_feather(cell_calls)
    .assign(total = lambda df: df[['cellranger-wf', 'cellranger-force-wf', 'cellranger3-wf']].sum(axis=1))
)
# Out:
#      cell_id  cellranger-wf  cellranger-force-wf  cellranger3-wf  droputils  \
# 0          1            0.0                  1.0             1.0          1
# 1          2            0.0                  0.0             1.0          0
# 2          3            0.0                  1.0             1.0          1
# 3          4            0.0                  0.0             1.0          0
# 4          5            0.0                  1.0             1.0          0
# 5          6            0.0                  1.0             1.0          1
# 6          7            0.0                  1.0             1.0          1
# 7          8            1.0                  1.0             1.0          1
# 8          9            0.0                  0.0             1.0          0
# 9         10            0.0                  0.0             1.0          1
# 10        11            0.0                  0.0             1.0          0
# ...
