# %% [markdown]
# # Parse New Gene Table

# %% [markdown]
# **from:** Maria D. Vibranovski
#
# Here attached is a list from Yong Zhang group based on our paper from 2010. But this is a still not published updated version that he shared with me but you can use.
#
# If you need details about the columns, please look at https://genome.cshlp.org/content/suppl/2010/08/27/gr.107334.110.DC1/SupplementalMaterial.pdf  table 2a.
#
# But mainly, what you need to select is the child genes with:
#
# gene_type = D or R or DL or RL
# m_type= M
# note that contains "chrX-"
#
# D and R stands for DNA-based Duplication and RNA-based duplication
# L means that the assignment of the parental genes is less reliable.
# M indicates that is between chromosome movement.
#
# Hope it helps. If you need I can parse for you. please, do not hesitate to ask. But I thought you would prefer a complete list where you can look at subsets.
#
# cheers
#
# Maria

# %%
import os
import sys
from pathlib import Path
import re

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd
from scipy.stats import fisher_exact, chi2_contingency
from scipy.stats.contingency import margins
import statsmodels.formula.api as smf

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from larval_gonad.notebook import Nb
from larval_gonad.plotting import make_figs
from larval_gonad.config import memory

# %%
# Setup notebook
nbconfig = Nb.setup_notebook(seurat_dir='../output/scrnaseq-wf/scrnaseq_combine_force')
# Out:
# last updated: 2019-03-14
# Git hash: 657094fd753a190e845ba8d3b2f5dbc8874cf279

# %%
def adjusted_residuals(observed, expected):
    resid = (observed - expected) / np.sqrt(expected)
    n = observed.sum().sum()
    rsum, csum = margins(observed)
    v = csum * rsum * (n - rsum) * (n - csum) / n**3
    return (observed - expected) / np.sqrt(v)

# %% [markdown]
# ## Import data from Maria

# %% [markdown]
# ## FBgn sanitizer

# %% [markdown]
# I don't know where these FBgns are from, so I need to sanitize them to my current annotation.

# %%
assembly = nbconfig.assembly
tag = nbconfig.tag
pth = Path(os.environ['REFERENCES_DIR'], f'{assembly}/{tag}/fb_annotation/{assembly}_{tag}.fb_annotation')

# Create an FBgn 
mapper = {}

for record in pd.read_csv(pth, sep='\t').to_records():
    mapper[record.primary_FBgn] = record.primary_FBgn
    
    try:
        for g in record.secondary_FBgn.split(','):
            mapper[g] = record.primary_FBgn
    except AttributeError:
        pass

# %%
autosomes = ['chr2L', 'chr2R', 'chr3L', 'chr3R']

# %%
movement = (
    pd.read_excel('../data/external/maria/dm6_ver78_genetype.new.xlsx')
    .query('gene_type == ["D", "R", "Dl", "Rl"] and m_type == "M"')
    .assign(child_chrom = lambda df: df.note.str.extract('(chr.*?)-'))
    .assign(parent_chrom = lambda df: df.note.str.extract('-(chr.*?)[:;]'))
    .assign(FBgn = lambda df: df.child_id.map(mapper))
    .assign(parent_FBgn = lambda df: df.parent_id.map(mapper))
    .drop(['child_id', 'parent_id', 'note', 'm_type'], axis=1)
    .dropna()
    .set_index('FBgn')
    .assign(moved_x_to_a = lambda df: (df.parent_chrom == 'chrX') & df.child_chrom.isin(autosomes))
    .assign(moved_a_to_a = lambda df: df.parent_chrom.isin(autosomes) & df.child_chrom.isin(autosomes))
    .assign(moved_a_to_x = lambda df: df.parent_chrom.isin(autosomes) & (df.child_chrom == 'chrX'))
    .query('moved_x_to_a | moved_a_to_a | moved_a_to_x')
)

movement.head()
# Out:
#             gene_type child_chrom parent_chrom  parent_FBgn  moved_x_to_a  \
# FBgn
# FBgn0000246        Dl       chr3R         chrX  FBgn0002873          True
# FBgn0002562         D        chrX        chr2L  FBgn0002563         False
# FBgn0003060         D       chr3R        chr2L  FBgn0032282         False
# FBgn0003086        Dl        chrX        chr3L  FBgn0036393         False
# FBgn0003357         R       chr3R        chr3L  FBgn0250815         False
#
#              moved_a_to_a  moved_a_to_x
# FBgn
# FBgn0000246         False         False
# FBgn0002562         False          True
# FBgn0003060          True         False
# FBgn0003086         False          True
# FBgn0003357          True         False

# %%
biomarkers = (
    nbconfig.seurat.get_biomarkers('res.0.6')
    .cluster.map(nbconfig.short_cluster_annot)
    .pipe(lambda x: x[x != 'UNK'])
    .to_frame()
    .reset_index()
    .groupby('FBgn')
    .apply(lambda x: '|'.join(x.cluster))
    .rename('biomakrer_cluster')
)

# %%
germ_comp = (
    pd.read_csv('../output/scrnaseq-wf/germcell_deg/gonia_vs_cytes.tsv', sep='\t')
    .assign(FBgn = lambda df: df.primary_FBgn)
    .assign(gonia = lambda df: df.avg_logFC > 0)
    .assign(cyte = lambda df: df.avg_logFC < 0)
    .set_index('FBgn')
    .loc[:, ['gonia', 'cyte']]
    .idxmax(axis=1)
    .rename('bias_gonia_vs_cyte')
)

# %%
biomarkers.head()
# Out:
# FBgn
# FBgn0000014       PC|TE
# FBgn0000015          TE
# FBgn0000017    TE|PC|LC
# FBgn0000024          PC
# FBgn0000028         E1º
# Name: biomakrer_cluster, dtype: object

# %%
df = (
    movement.join(biomarkers, how='left')
    .join(germ_comp.rename('bias_gonia_vs_cyte_child'), how='left')
    .join(germ_comp.rename('bias_gonia_vs_cyte_parent'), on='parent_FBgn', how='left')
)

# %%
df
# Out:
#             gene_type child_chrom parent_chrom  parent_FBgn  moved_x_to_a  \
# FBgn
# FBgn0000246        Dl       chr3R         chrX  FBgn0002873          True
# FBgn0002562         D        chrX        chr2L  FBgn0002563         False
# FBgn0003060         D       chr3R        chr2L  FBgn0032282         False
# FBgn0003086        Dl        chrX        chr3L  FBgn0036393         False
# FBgn0003357         R       chr3R        chr3L  FBgn0250815         False
# FBgn0004414        Rl       chr3L        chr2L  FBgn0283658         False
# FBgn0010549        Dl       chr2R        chr3R  FBgn0039645         False
# FBgn0011559        Dl       chr2L        chr3L  FBgn0052133         False
# FBgn0015008        Rl       chr3R         chrX  FBgn0025633          True
# FBgn0015025        Rl       chr3L        chr3R  FBgn0039860         False
# FBgn0015035         D       chr2L        chr2R  FBgn0014469         False
# FBgn0015520         R       chr3R         chrX  FBgn0004227          True
# FBgn0016080        Dl        chrX        chr2R  FBgn0033438         False
# FBgn0025616        Dl        chrX        chr2L  FBgn0051952         False
# FBgn0026361         R       chr2R        chr3R  FBgn0014029         False
# FBgn0026754         D       chr2R        chr2L  FBgn0040262         False
# FBgn0027494         D       chr3R         chrX  FBgn0285947          True
# FBgn0027864        Rl        chrX        chr2L  FBgn0032907         False
# FBgn0028430        Dl       chr2L        chr2R  FBgn0054040         False
# FBgn0028856        Dl       chr2L        chr2R  FBgn0034826         False
# FBgn0028862        Dl       chr2L        chr2R  FBgn0033427         False
# FBgn0028870        Dl       chr2L        chr2R  FBgn0050362         False
# FBgn0028900        Dl       chr2L         chrX  FBgn0085446          True
# FBgn0028935        Dl       chr2L        chr3R  FBgn0263236         False
# FBgn0029172         R       chr3L        chr3R  FBgn0038130         False
# FBgn0029694         D        chrX        chr3R  FBgn0037910         False
# FBgn0029717        Dl        chrX        chr2R  FBgn0034099         False
# FBgn0029811        Rl        chrX        chr3L  FBgn0052029         False
# FBgn0029816        Rl        chrX        chr2R  FBgn0033669         False
# FBgn0030016        Dl        chrX        chr2R  FBgn0033041         False
# ...               ...         ...          ...          ...           ...
# FBgn0262001        Dl       chr2L        chr3L  FBgn0037127         False
# FBgn0262351        Dl       chr3L         chrX  FBgn0029657          True
# FBgn0262360        Dl       chr2R        chr3R  FBgn0037384         False
# FBgn0262478        Rl       chr2R        chr3L  FBgn0026189         False
# FBgn0262484        Dl       chr3L         chrX  FBgn0262536          True
# FBgn0262487        Dl        chrX        chr3L  FBgn0002872         False
# FBgn0262529        Dl       chr3L         chrX  FBgn0030107          True
# FBgn0262583        Dl       chr2R        chr3L  FBgn0036717         False
# FBgn0262605        Rl       chr3R        chr2R  FBgn0260763         False
# FBgn0262900        Dl        chrX        chr2L  FBgn0051862         False
# FBgn0262962        Dl       chr3R         chrX  FBgn0266019          True
# FBgn0263037        Dl       chr2L        chr3R  FBgn0051439         False
# FBgn0263040        Dl       chr3R        chr2R  FBgn0053459         False
# FBgn0263082        Dl       chr2L        chr3R  FBgn0003137         False
# FBgn0263087        Rl       chr2L         chrX  FBgn0030034          True
# FBgn0263647        Dl       chr3L        chr3R  FBgn0038532         False
# FBgn0264077         R        chrX        chr3R  FBgn0015622         False
# FBgn0264342        Dl       chr2L        chr3R  FBgn0051439         False
# FBgn0264343        Dl       chr2L         chrX  FBgn0029639          True
# FBgn0264395        Dl        chrX        chr3L  FBgn0001254         False
# FBgn0264739        Dl        chrX        chr3L  FBgn0260965         False
# FBgn0264911        Dl       chr2R         chrX  FBgn0262536          True
# FBgn0265041        Rl       chr3R         chrX  FBgn0031059          True
# FBgn0265265        Dl        chrX        chr3L  FBgn0036173         False
# FBgn0265606        Dl       chr3R        chr2R  FBgn0023175         False
# FBgn0265785        Dl       chr2L         chrX  FBgn0262740          True
# FBgn0265835        Dl       chr2R        chr3L  FBgn0262139         False
# FBgn0266436        Rl       chr3L        chr2R  FBgn0267792         False
# FBgn0266721         R       chr3R        chr2R  FBgn0028552         False
# FBgn0267106        Dl       chr3R        chr3L  FBgn0029167         False
#
#              moved_a_to_a  moved_a_to_x biomakrer_cluster  \
# FBgn
# FBgn0000246         False         False               NaN
# FBgn0002562         False          True               NaN
# FBgn0003060          True         False               NaN
# FBgn0003086         False          True               NaN
# FBgn0003357          True         False               NaN
# FBgn0004414          True         False               NaN
# FBgn0010549          True         False               NaN
# FBgn0011559          True         False               NaN
# FBgn0015008         False         False       E1º|L1º|M1º
# FBgn0015025          True         False               NaN
# FBgn0015035          True         False               NaN
# FBgn0015520         False         False                SP
# FBgn0016080         False          True               NaN
# FBgn0025616         False          True               M1º
# FBgn0026361          True         False               NaN
# FBgn0026754          True         False               NaN
# FBgn0027494         False         False            E1º|SP
# FBgn0027864         False          True               NaN
# FBgn0028430          True         False               NaN
# FBgn0028856          True         False       M1º|E1º|L1º
# FBgn0028862          True         False               NaN
# FBgn0028870          True         False       M1º|L1º|E1º
# FBgn0028900         False         False               E1º
# FBgn0028935          True         False               NaN
# FBgn0029172          True         False               NaN
# FBgn0029694         False          True               NaN
# FBgn0029717         False          True       E1º|L1º|M1º
# FBgn0029811         False          True               NaN
# FBgn0029816         False          True               M1º
# FBgn0030016         False          True               NaN
# ...                   ...           ...               ...
# FBgn0262001          True         False               NaN
# FBgn0262351         False         False           M1º|L1º
# FBgn0262360          True         False           M1º|L1º
# FBgn0262478          True         False           L1º|M1º
# FBgn0262484         False         False               NaN
# FBgn0262487         False          True       M1º|L1º|E1º
# FBgn0262529         False         False               NaN
# FBgn0262583          True         False               NaN
# FBgn0262605          True         False               NaN
# FBgn0262900         False          True               NaN
# FBgn0262962         False         False               NaN
# FBgn0263037          True         False               NaN
# FBgn0263040          True         False               NaN
# FBgn0263082          True         False               NaN
# FBgn0263087         False         False               NaN
# FBgn0263647          True         False           M1º|L1º
# FBgn0264077         False          True               E1º
# FBgn0264342          True         False               NaN
# FBgn0264343         False         False               NaN
# FBgn0264395         False          True                SP
# FBgn0264739         False          True       L1º|M1º|E1º
# FBgn0264911         False         False               NaN
# FBgn0265041         False         False           M1º|E1º
# FBgn0265265         False          True       E1º|L1º|M1º
# FBgn0265606          True         False           M1º|L1º
# FBgn0265785         False         False               NaN
# FBgn0265835          True         False               NaN
# FBgn0266436          True         False       L1º|M1º|E1º
# FBgn0266721          True         False               NaN
# FBgn0267106          True         False               NaN
#
#             bias_gonia_vs_cyte_child bias_gonia_vs_cyte_parent
# FBgn
# FBgn0000246                      NaN                       NaN
# FBgn0002562                      NaN                       NaN
# FBgn0003060                      NaN                       NaN
# FBgn0003086                      NaN                       NaN
# FBgn0003357                      NaN                       NaN
# FBgn0004414                      NaN                       NaN
# FBgn0010549                      NaN                       NaN
# FBgn0011559                      NaN                       NaN
# FBgn0015008                     cyte                       NaN
# FBgn0015025                      NaN                       NaN
# FBgn0015035                      NaN                       NaN
# FBgn0015520                    gonia                       NaN
# FBgn0016080                      NaN                       NaN
# FBgn0025616                     cyte                      cyte
# FBgn0026361                      NaN                     gonia
# FBgn0026754                      NaN                       NaN
# FBgn0027494                    gonia                     gonia
# FBgn0027864                      NaN                       NaN
# FBgn0028430                      NaN                       NaN
# FBgn0028856                     cyte                      cyte
# FBgn0028862                      NaN                       NaN
# FBgn0028870                     cyte                      cyte
# FBgn0028900                     cyte                       NaN
# FBgn0028935                      NaN                       NaN
# FBgn0029172                      NaN                       NaN
# FBgn0029694                      NaN                      cyte
# FBgn0029717                     cyte                      cyte
# FBgn0029811                      NaN                       NaN
# FBgn0029816                     cyte                      cyte
# FBgn0030016                      NaN                       NaN
# ...                              ...                       ...
# FBgn0262001                      NaN                       NaN
# FBgn0262351                     cyte                      cyte
# FBgn0262360                     cyte                       NaN
# FBgn0262478                     cyte                       NaN
# FBgn0262484                      NaN                       NaN
# FBgn0262487                     cyte                       NaN
# FBgn0262529                      NaN                       NaN
# FBgn0262583                      NaN                       NaN
# FBgn0262605                      NaN                       NaN
# FBgn0262900                      NaN                       NaN
# FBgn0262962                      NaN                       NaN
# FBgn0263037                      NaN                       NaN
# FBgn0263040                      NaN                       NaN
# FBgn0263082                      NaN                       NaN
# FBgn0263087                      NaN                       NaN
# FBgn0263647                     cyte                       NaN
# FBgn0264077                     cyte                       NaN
# FBgn0264342                      NaN                       NaN
# FBgn0264343                      NaN                       NaN
# FBgn0264395                    gonia                       NaN
# FBgn0264739                     cyte                       NaN
# FBgn0264911                      NaN                       NaN
# FBgn0265041                     cyte                       NaN
# FBgn0265265                     cyte                      cyte
# FBgn0265606                     cyte                     gonia
# FBgn0265785                      NaN                       NaN
# FBgn0265835                      NaN                       NaN
# FBgn0266436                     cyte                       NaN
# FBgn0266721                      NaN                       NaN
# FBgn0267106                      NaN                       NaN
#
# [245 rows x 10 columns]

# %%
out_order = [
    'child_chrom',
    'parent_chrom',
    'parent_FBgn',
    'gene_type',
    'moved_x_to_a',
    'moved_a_to_a',
    'moved_a_to_x',
    'biomakrer_cluster',
    'bias_gonia_vs_cyte_child',
    'bias_gonia_vs_cyte_parent'
]

df.reindex(columns=out_order).reset_index().rename({'FBgn': 'child_FBgn'}, axis=1).fillna('nan').to_csv('../output/notebook/2019-03-14_movement_data.csv', index=None)

# %%
print('\n'.join(out_order))
# Out:
# child_chrom
# parent_chrom
# parent_FBgn
# gene_type
# moved_x_to_a
# moved_a_to_a
# moved_a_to_x
# biomakrer_cluster
# bias_gonia_vs_cyte_child
# bias_gonia_vs_cyte_parent
