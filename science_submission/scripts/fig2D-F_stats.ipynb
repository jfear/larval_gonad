# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

from larval_gonad.stats import run_chisq

pd.options.display.max_rows = 200

# %% [markdown]
#  # Adult Bulk

# %%
adult_bulk = pd.read_feather("../output/expression-atlas-wf/w1118_gene_counts.feather")
adult_ct = (
    adult_bulk
    .assign(flag_on=lambda x: x.Count >= 5)
    .groupby(["tissue", "chrom"])
    .flag_on.sum()
    .unstack()
    .reindex(index=["testis", "ovary"], columns="X,2L,2R,3L,3R,4,Y".split(","))
)  # type: pd.DataFrame

# run_chisq(adult_ct).loc[("testis", ["observed", "adj std residual", "fdr q-value"]),:]
run_chisq(adult_ct).loc[(slice(None), ["observed", "adj std residual", "fdr q-value"]),:]
# Out:
# 𝛘^2: 62.2273, p-value: 0.0000, df: 6
# chrom                            X         2L         2R         3L  \
# tissue type
# ovary  observed          4634.0000  4818.0000  5395.0000  5142.0000
#        adj std residual     5.0496    -3.5770     0.2172     0.2919
#        fdr q-value          0.0000     0.0016     0.3896     0.3896
# testis observed          5499.0000  6662.0000  6994.0000  6657.0000
#        adj std residual    -5.0496     3.5770    -0.2172    -0.2919
#        fdr q-value          0.0000     0.0016     0.3896     0.3896
#
# chrom                           3R         4        Y
# tissue type
# ovary  observed          6364.0000  246.0000   0.0000
#        adj std residual    -1.7339    1.8987  -4.9609
#        fdr q-value          0.1242    0.1151   0.0000
# testis observed          8489.0000  271.0000  32.0000
#        adj std residual     1.7339   -1.8987   4.9609
#        fdr q-value          0.1242    0.1151   0.0000

# %%
fbgn2symbol = pd.read_feather("../references/gene_annotation_dmel_r6-26.feather", columns=["FBgn", "gene_symbol"]).set_index("FBgn").squeeze()
ovary_y_fbgns = adult_bulk.query("tissue == 'ovary' & chrom == 'Y' & Count > 0")
display(ovary_y_fbgns.merge(fbgn2symbol, on="FBgn").set_index(["FBgn", "gene_symbol"]).sort_values("Count", ascending=False))
fbgn2symbol.reindex(ovary_y_fbgns.FBgn.unique()).to_frame()
# Out:
#                               sample_ID  Count  stage tissue rep data_source  \
# FBgn        gene_symbol
# FBgn0058064 ARY          adult_ovary_r4      1  adult  ovary   4     RNA-Seq
# FBgn0267433 kl-5         adult_ovary_r2      1  adult  ovary   2     RNA-Seq
#             kl-5         adult_ovary_r3      1  adult  ovary   3     RNA-Seq
# FBgn0267592 CCY          adult_ovary_r1      1  adult  ovary   1     RNA-Seq
#
#                         chrom
# FBgn        gene_symbol
# FBgn0058064 ARY             Y
# FBgn0267433 kl-5            Y
#             kl-5            Y
# FBgn0267592 CCY             Y
#             gene_symbol
# FBgn
# FBgn0058064         ARY
# FBgn0267433        kl-5
# FBgn0267592         CCY

# %% [markdown]
#  # Larval Bulk

# %%
larval_bulk = pd.read_feather("../output/bulk2-rnaseq-wf/testis_ovary_counts.feather")
larval_ct = (
    larval_bulk
    .assign(flag_on=lambda x: x.Count >= 5)
    .groupby(["tissue", "chrom"])
    .flag_on.sum()
    .unstack()
    .reindex(index=["testis", "ovary"], columns="X,2L,2R,3L,3R,4,Y".split(","))
)  # type: pd.DataFrame

run_chisq(larval_ct).loc[("testis", ["observed", "adj std residual", "fdr q-value"]),:]
# Out:
# 𝛘^2: 145.1302, p-value: 0.0000, df: 6
# chrom                            X         2L         2R         3L  \
# tissue type
# testis observed          7373.0000  9194.0000  9291.0000  9294.0000
#        adj std residual    -7.5711     6.5045    -2.1991     1.8733
#        fdr q-value          0.0000     0.0000     0.0498     0.0805
#
# chrom                            3R         4        Y
# tissue type
# testis observed          11419.0000  335.0000  80.0000
#        adj std residual      1.0686   -3.0093   6.8151
#        fdr q-value           0.2254    0.0075   0.0000

# %%
fbgn2symbol = pd.read_feather("../references/gene_annotation_dmel_r6-26.feather", columns=["FBgn", "gene_symbol"]).set_index("FBgn").squeeze()
ovary_y_fbgns = larval_bulk.query("tissue == 'ovary' & chrom == 'Y' & Count > 0")
display(ovary_y_fbgns.merge(fbgn2symbol, on="FBgn").set_index(["FBgn", "gene_symbol"]).sort_values("Count", ascending=False))
print(ovary_y_fbgns.Count.sum())
fbgn2symbol.reindex(ovary_y_fbgns.FBgn.unique()).to_frame()
# Out:
#                         sample_ID  Count stage tissue rep data_source chrom
# FBgn        gene_symbol
# FBgn0085789 CR41506        A4_OCP     15    L3  ovary   4     RNA-Seq     Y
#             CR41506        A3_OCP     15    L3  ovary   3     RNA-Seq     Y
#             CR41506        A2_OCP     13    L3  ovary   2     RNA-Seq     Y
# FBgn0265047 FDY            A1_OCP     12    L3  ovary   1     RNA-Seq     Y
# FBgn0085789 CR41506        A1_OCP      7    L3  ovary   1     RNA-Seq     Y
# FBgn0085792 CR41509        A3_OCP      5    L3  ovary   3     RNA-Seq     Y
# FBgn0085790 CR41507        A1_OCP      4    L3  ovary   1     RNA-Seq     Y
# FBgn0085792 CR41509        A2_OCP      3    L3  ovary   2     RNA-Seq     Y
# FBgn0085520 CR40801        A2_OCP      3    L3  ovary   2     RNA-Seq     Y
# FBgn0085790 CR41507        A2_OCP      3    L3  ovary   2     RNA-Seq     Y
#             CR41507        A4_OCP      3    L3  ovary   4     RNA-Seq     Y
# FBgn0085792 CR41509        A4_OCP      3    L3  ovary   4     RNA-Seq     Y
#             CR41509        A1_OCP      3    L3  ovary   1     RNA-Seq     Y
# FBgn0261399 Pp1-Y1         A1_OCP      2    L3  ovary   1     RNA-Seq     Y
# FBgn0265047 FDY            A3_OCP      2    L3  ovary   3     RNA-Seq     Y
#             FDY            A4_OCP      2    L3  ovary   4     RNA-Seq     Y
# FBgn0001313 kl-2           A1_OCP      2    L3  ovary   1     RNA-Seq     Y
# FBgn0085520 CR40801        A1_OCP      2    L3  ovary   1     RNA-Seq     Y
# FBgn0267592 CCY            A1_OCP      2    L3  ovary   1     RNA-Seq     Y
# FBgn0265047 FDY            A2_OCP      1    L3  ovary   2     RNA-Seq     Y
# FBgn0046698 Pp1-Y2         A1_OCP      1    L3  ovary   1     RNA-Seq     Y
# FBgn0058064 ARY            A1_OCP      1    L3  ovary   1     RNA-Seq     Y
# FBgn0267489 PRY            A1_OCP      1    L3  ovary   1     RNA-Seq     Y
# FBgn0267592 CCY            A4_OCP      1    L3  ovary   4     RNA-Seq     Y
# 106
#             gene_symbol
# FBgn
# FBgn0001313        kl-2
# FBgn0046698      Pp1-Y2
# FBgn0058064         ARY
# FBgn0085520     CR40801
# FBgn0085789     CR41506
# FBgn0085790     CR41507
# FBgn0085792     CR41509
# FBgn0261399      Pp1-Y1
# FBgn0265047         FDY
# FBgn0267489         PRY
# FBgn0267592         CCY

# %% [markdown]
#  # Larval scRNA-Seq

# %%
sc = (
    pd.read_feather("../output/seurat3-cluster-wf/aggegated_gene_counts_by_germ_soma.feather")
    .assign(cell_type=lambda x: x.cell_type.replace({"Germline": "Germline", "Cyst Lineage": "Somatic", "Other Somatic": "Somatic"}))
)

sc_ct = (
    sc
    .assign(flag_on=lambda x: x.Count >= 5)
    .groupby(["cell_type", "chrom"])
    .flag_on.sum()
    .unstack()
    .reindex(index=["Germline", "Somatic"], columns="X,2L,2R,3L,3R,4,Y".split(","))
) # type: pd.DataFrame

run_chisq(sc_ct).loc[("Germline", ["observed", "adj std residual", "fdr q-value"]),:]
# Out:
# 𝛘^2: 31.5933, p-value: 0.0000, df: 6
# chrom                               X         2L         2R         3L  \
# cell_type type
# Germline  observed          5123.0000  6330.0000  6425.0000  6409.0000
#           adj std residual    -2.8791     1.5344    -0.8913     1.1611
#           fdr q-value          0.0221     0.2868     0.3387     0.3387
#
# chrom                              3R         4        Y
# cell_type type
# Germline  observed          7791.0000  228.0000  71.0000
#           adj std residual     0.5722   -0.7200   4.5056
#           fdr q-value          0.3387    0.3387   0.0001

# %%
fbgn2symbol = pd.read_feather("../references/gene_annotation_dmel_r6-26.feather", columns=["FBgn", "gene_symbol"]).set_index("FBgn").squeeze()
somatic_y_fbgns = sc.query("cell_type == 'Somatic' & chrom == 'Y' & Count > 0")
display(somatic_y_fbgns.merge(fbgn2symbol, on="FBgn").set_index(["FBgn", "gene_symbol"]).sort_values("Count", ascending=False))
print(somatic_y_fbgns.Count.sum())
fbgn2symbol.reindex(somatic_y_fbgns.FBgn.unique()).to_frame()
# Out:
#                               rep cell_type  Count  tissue stage  \
# FBgn        gene_symbol
# FBgn0267422 CR45775          rep3   Somatic    175  testis    L3
#             CR45775          rep2   Somatic    113  testis    L3
# FBgn0267412 CG45765          rep3   Somatic     87  testis    L3
# FBgn0058064 ARY              rep3   Somatic     86  testis    L3
# FBgn0267422 CR45775          rep3   Somatic     78  testis    L3
# FBgn0267412 CG45765          rep1   Somatic     72  testis    L3
#             CG45765          rep2   Somatic     68  testis    L3
# FBgn0058064 ARY              rep3   Somatic     54  testis    L3
# FBgn0046698 Pp1-Y2           rep3   Somatic     53  testis    L3
# FBgn0058064 ARY              rep2   Somatic     50  testis    L3
# FBgn0261399 Pp1-Y1           rep3   Somatic     40  testis    L3
# FBgn0046698 Pp1-Y2           rep2   Somatic     33  testis    L3
# FBgn0267412 CG45765          rep3   Somatic     28  testis    L3
# FBgn0261399 Pp1-Y1           rep2   Somatic     28  testis    L3
# FBgn0267433 kl-5             rep3   Somatic     26  testis    L3
# FBgn0046698 Pp1-Y2           rep3   Somatic     24  testis    L3
# FBgn0267422 CR45775          rep1   Somatic     23  testis    L3
# FBgn0046697 Ppr-Y            rep2   Somatic     21  testis    L3
# FBgn0267862 CR46150          rep2   Somatic     19  testis    L3
# FBgn0085831 CR42201          rep1   Somatic     19  testis    L3
# FBgn0267422 CR45775          rep2   Somatic     19  testis    L3
# FBgn0046697 Ppr-Y            rep3   Somatic     18  testis    L3
# FBgn0267862 CR46150          rep3   Somatic     18  testis    L3
# FBgn0267432 kl-3             rep3   Somatic     17  testis    L3
# FBgn0267897 CR46185          rep3   Somatic     17  testis    L3
# FBgn0267492 Mst77Y-7         rep3   Somatic     17  testis    L3
# FBgn0267433 kl-5             rep2   Somatic     16  testis    L3
# FBgn0001313 kl-2             rep3   Somatic     15  testis    L3
# FBgn0267433 kl-5             rep3   Somatic     14  testis    L3
# FBgn0267592 CCY              rep3   Somatic     14  testis    L3
# FBgn0046323 ORY              rep3   Somatic     12  testis    L3
# FBgn0267492 Mst77Y-7         rep3   Somatic     12  testis    L3
# FBgn0046697 Ppr-Y            rep3   Somatic     12  testis    L3
# FBgn0267897 CR46185          rep2   Somatic     11  testis    L3
# FBgn0261399 Pp1-Y1           rep3   Somatic     11  testis    L3
# FBgn0267412 CG45765          rep2   Somatic     10  testis    L3
# FBgn0058064 ARY              rep2   Somatic     10  testis    L3
# FBgn0085644 CR41423          rep3   Somatic      9  testis    L3
#             CR41423          rep2   Somatic      9  testis    L3
# FBgn0267592 CCY              rep2   Somatic      9  testis    L3
# FBgn0267432 kl-3             rep3   Somatic      8  testis    L3
# FBgn0085644 CR41423          rep3   Somatic      8  testis    L3
# FBgn0265047 FDY              rep3   Somatic      8  testis    L3
# FBgn0267862 CR46150          rep3   Somatic      7  testis    L3
# FBgn0267492 Mst77Y-7         rep1   Somatic      7  testis    L3
#             Mst77Y-7         rep2   Somatic      7  testis    L3
# FBgn0001313 kl-2             rep2   Somatic      7  testis    L3
# FBgn0085789 CR41506          rep3   Somatic      7  testis    L3
# FBgn0085831 CR42201          rep3   Somatic      7  testis    L3
# FBgn0267592 CCY              rep3   Somatic      6  testis    L3
# FBgn0267489 PRY              rep2   Somatic      6  testis    L3
# FBgn0267879 CR46167          rep3   Somatic      6  testis    L3
# FBgn0261399 Pp1-Y1           rep2   Somatic      5  testis    L3
# FBgn0046698 Pp1-Y2           rep2   Somatic      5  testis    L3
#             Pp1-Y2           rep1   Somatic      5  testis    L3
# FBgn0267879 CR46167          rep2   Somatic      5  testis    L3
# FBgn0001313 kl-2             rep3   Somatic      4  testis    L3
# FBgn0283435 CR46279          rep2   Somatic      4  testis    L3
# FBgn0085789 CR41506          rep3   Somatic      4  testis    L3
# FBgn0267432 kl-3             rep2   Somatic      4  testis    L3
# FBgn0267862 CR46150          rep1   Somatic      3  testis    L3
# FBgn0046323 ORY              rep3   Somatic      3  testis    L3
# FBgn0085789 CR41506          rep2   Somatic      3  testis    L3
# FBgn0267433 kl-5             rep2   Somatic      3  testis    L3
# FBgn0267432 kl-3             rep2   Somatic      3  testis    L3
# FBgn0085831 CR42201          rep2   Somatic      3  testis    L3
# FBgn0267449 WDY              rep3   Somatic      3  testis    L3
# FBgn0265047 FDY              rep3   Somatic      3  testis    L3
# FBgn0267418 CR45771          rep3   Somatic      3  testis    L3
# FBgn0046697 Ppr-Y            rep2   Somatic      2  testis    L3
# FBgn0267489 PRY              rep3   Somatic      2  testis    L3
# FBgn0261399 Pp1-Y1           rep1   Somatic      2  testis    L3
# FBgn0267449 WDY              rep2   Somatic      2  testis    L3
# FBgn0267882 CR46170          rep3   Somatic      2  testis    L3
# FBgn0267492 Mst77Y-7         rep2   Somatic      2  testis    L3
# FBgn0267418 CR45771          rep1   Somatic      2  testis    L3
# FBgn0058064 ARY              rep1   Somatic      2  testis    L3
# FBgn0262795 CR43176          rep3   Somatic      2  testis    L3
# FBgn0267897 CR46185          rep3   Somatic      2  testis    L3
# FBgn0267862 CR46150          rep2   Somatic      2  testis    L3
# FBgn0267412 CG45765          rep1   Somatic      2  testis    L3
# FBgn0267872 CR46160          rep3   Somatic      2  testis    L3
# FBgn0046323 ORY              rep2   Somatic      1  testis    L3
# FBgn0259863 Su(Ste):CR42432  rep3   Somatic      1  testis    L3
# FBgn0046323 ORY              rep2   Somatic      1  testis    L3
# FBgn0267872 CR46160          rep2   Somatic      1  testis    L3
# FBgn0085831 CR42201          rep3   Somatic      1  testis    L3
# FBgn0265047 FDY              rep2   Somatic      1  testis    L3
#             FDY              rep2   Somatic      1  testis    L3
# FBgn0267882 CR46170          rep3   Somatic      1  testis    L3
# FBgn0267897 CR46185          rep1   Somatic      1  testis    L3
# FBgn0046323 ORY              rep1   Somatic      1  testis    L3
# FBgn0267899 CR46187          rep2   Somatic      1  testis    L3
# FBgn0267900 CR46188          rep3   Somatic      1  testis    L3
# FBgn0262795 CR43176          rep2   Somatic      1  testis    L3
# FBgn0267879 CR46167          rep3   Somatic      1  testis    L3
# FBgn0259861 Su(Ste):CR42430  rep3   Somatic      1  testis    L3
# FBgn0259863 Su(Ste):CR42432  rep2   Somatic      1  testis    L3
# FBgn0267592 CCY              rep1   Somatic      1  testis    L3
# FBgn0267422 CR45775          rep1   Somatic      1  testis    L3
# FBgn0267432 kl-3             rep1   Somatic      1  testis    L3
# FBgn0259853 Su(Ste):CR42422  rep3   Somatic      1  testis    L3
# FBgn0085790 CR41507          rep2   Somatic      1  testis    L3
# FBgn0267418 CR45771          rep2   Somatic      1  testis    L3
# FBgn0267433 kl-5             rep1   Somatic      1  testis    L3
# FBgn0259856 Su(Ste):CR42425  rep2   Somatic      1  testis    L3
# FBgn0259857 Su(Ste):CR42426  rep2   Somatic      1  testis    L3
# FBgn0085644 CR41423          rep2   Somatic      1  testis    L3
# FBgn0267449 WDY              rep2   Somatic      1  testis    L3
#             WDY              rep3   Somatic      1  testis    L3
# FBgn0001313 kl-2             rep2   Somatic      1  testis    L3
# FBgn0267489 PRY              rep2   Somatic      1  testis    L3
# FBgn0085644 CR41423          rep1   Somatic      1  testis    L3
# FBgn0267492 Mst77Y-7         rep1   Somatic      1  testis    L3
# FBgn0058064 ARY              rep1   Somatic      1  testis    L3
# FBgn0259845 Su(Ste):CR42414  rep3   Somatic      1  testis    L3
# FBgn0283435 CR46279          rep3   Somatic      1  testis    L3
#
#                                     sample_ID data_source chrom
# FBgn        gene_symbol
# FBgn0267422 CR45775          L3_scRNAseq_rep3   scRNA-Seq     Y
#             CR45775          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267412 CG45765          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0058064 ARY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267422 CR45775          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267412 CG45765          L3_scRNAseq_rep1   scRNA-Seq     Y
#             CG45765          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0058064 ARY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046698 Pp1-Y2           L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0058064 ARY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0261399 Pp1-Y1           L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046698 Pp1-Y2           L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267412 CG45765          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0261399 Pp1-Y1           L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267433 kl-5             L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046698 Pp1-Y2           L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267422 CR45775          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0046697 Ppr-Y            L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267862 CR46150          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085831 CR42201          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267422 CR45775          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0046697 Ppr-Y            L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267862 CR46150          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267432 kl-3             L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267897 CR46185          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267492 Mst77Y-7         L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267433 kl-5             L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0001313 kl-2             L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267433 kl-5             L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267592 CCY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046323 ORY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267492 Mst77Y-7         L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046697 Ppr-Y            L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267897 CR46185          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0261399 Pp1-Y1           L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267412 CG45765          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0058064 ARY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085644 CR41423          L3_scRNAseq_rep3   scRNA-Seq     Y
#             CR41423          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267592 CCY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267432 kl-3             L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0085644 CR41423          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0265047 FDY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267862 CR46150          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267492 Mst77Y-7         L3_scRNAseq_rep1   scRNA-Seq     Y
#             Mst77Y-7         L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0001313 kl-2             L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085789 CR41506          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0085831 CR42201          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267592 CCY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267489 PRY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267879 CR46167          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0261399 Pp1-Y1           L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0046698 Pp1-Y2           L3_scRNAseq_rep2   scRNA-Seq     Y
#             Pp1-Y2           L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267879 CR46167          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0001313 kl-2             L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0283435 CR46279          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085789 CR41506          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267432 kl-3             L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267862 CR46150          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0046323 ORY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0085789 CR41506          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267433 kl-5             L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267432 kl-3             L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085831 CR42201          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267449 WDY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0265047 FDY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267418 CR45771          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046697 Ppr-Y            L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267489 PRY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0261399 Pp1-Y1           L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267449 WDY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267882 CR46170          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267492 Mst77Y-7         L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267418 CR45771          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0058064 ARY              L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0262795 CR43176          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267897 CR46185          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267862 CR46150          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267412 CG45765          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267872 CR46160          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046323 ORY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0259863 Su(Ste):CR42432  L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0046323 ORY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267872 CR46160          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085831 CR42201          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0265047 FDY              L3_scRNAseq_rep2   scRNA-Seq     Y
#             FDY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267882 CR46170          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0267897 CR46185          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0046323 ORY              L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267899 CR46187          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267900 CR46188          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0262795 CR43176          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267879 CR46167          L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0259861 Su(Ste):CR42430  L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0259863 Su(Ste):CR42432  L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267592 CCY              L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267422 CR45775          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267432 kl-3             L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0259853 Su(Ste):CR42422  L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0085790 CR41507          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267418 CR45771          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267433 kl-5             L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0259856 Su(Ste):CR42425  L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0259857 Su(Ste):CR42426  L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085644 CR41423          L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267449 WDY              L3_scRNAseq_rep2   scRNA-Seq     Y
#             WDY              L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0001313 kl-2             L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0267489 PRY              L3_scRNAseq_rep2   scRNA-Seq     Y
# FBgn0085644 CR41423          L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0267492 Mst77Y-7         L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0058064 ARY              L3_scRNAseq_rep1   scRNA-Seq     Y
# FBgn0259845 Su(Ste):CR42414  L3_scRNAseq_rep3   scRNA-Seq     Y
# FBgn0283435 CR46279          L3_scRNAseq_rep3   scRNA-Seq     Y
# 1575
#                  gene_symbol
# FBgn
# FBgn0001313             kl-2
# FBgn0046323              ORY
# FBgn0046697            Ppr-Y
# FBgn0046698           Pp1-Y2
# FBgn0058064              ARY
# FBgn0085644          CR41423
# FBgn0085789          CR41506
# FBgn0085790          CR41507
# FBgn0085831          CR42201
# FBgn0259845  Su(Ste):CR42414
# FBgn0259853  Su(Ste):CR42422
# FBgn0259856  Su(Ste):CR42425
# FBgn0259857  Su(Ste):CR42426
# FBgn0259861  Su(Ste):CR42430
# FBgn0259863  Su(Ste):CR42432
# FBgn0261399           Pp1-Y1
# FBgn0262795          CR43176
# FBgn0265047              FDY
# FBgn0267412          CG45765
# FBgn0267418          CR45771
# FBgn0267422          CR45775
# FBgn0267432             kl-3
# FBgn0267433             kl-5
# FBgn0267449              WDY
# FBgn0267489              PRY
# FBgn0267492         Mst77Y-7
# FBgn0267592              CCY
# FBgn0267862          CR46150
# FBgn0267872          CR46160
# FBgn0267879          CR46167
# FBgn0267882          CR46170
# FBgn0267897          CR46185
# FBgn0267899          CR46187
# FBgn0267900          CR46188
# FBgn0283435          CR46279
